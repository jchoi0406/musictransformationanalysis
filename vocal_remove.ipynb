# %%
# !pip install demucs
# Out:
# Collecting demucs
#   Downloading demucs-4.0.1.tar.gz (1.2 MB)
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#      ---------------------------------------- 1.2/1.2 MB 6.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting dora-search (from demucs)
#   Downloading dora_search-0.1.12.tar.gz (87 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting einops (from demucs)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting julius>=0.2.3 (from demucs)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting lameenc>=1.2 (from demucs)
#   Downloading lameenc-1.8.1-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting openunmix (from demucs)
#   Downloading openunmix-1.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from demucs) (6.0.2)
# Requirement already satisfied: torch>=1.8.1 in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from demucs) (2.7.1)
# Collecting torchaudio>=0.8 (from demucs)
#   Downloading torchaudio-2.8.0-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: tqdm in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from demucs) (4.67.1)
# Requirement already satisfied: filelock in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from torch>=1.8.1->demucs) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from torch>=1.8.1->demucs) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from torch>=1.8.1->demucs) (1.14.0)
# Requirement already satisfied: networkx in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from torch>=1.8.1->demucs) (3.5)
# Requirement already satisfied: jinja2 in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from torch>=1.8.1->demucs) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from torch>=1.8.1->demucs) (2025.5.1)
# Requirement already satisfied: setuptools in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from torch>=1.8.1->demucs) (80.9.0)
# Collecting torch>=1.8.1 (from demucs)
#   Downloading torch-2.8.0-cp312-cp312-win_amd64.whl.metadata (30 kB)
# Collecting omegaconf (from dora-search->demucs)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting retrying (from dora-search->demucs)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting submitit (from dora-search->demucs)
#   Downloading submitit-1.5.3-py3-none-any.whl.metadata (7.9 kB)
# Collecting treetable (from dora-search->demucs)
#   Downloading treetable-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from openunmix->demucs) (2.2.6)
# Requirement already satisfied: colorama in c:\users\jiyon\desktop\programming_projects\unsw\musictransformationanalysis\.venv\lib\site-packages (from tqdm->demucs) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users
downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading submitit-1.5.3-py3-none-any.whl (75 kB)
# Downloading treetable-0.2.6-py3-none-any.whl (7.4 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Building wheels for collected packages: demucs, julius, dora-search, antlr4-python3-runtime
#   Building wheel for demucs (pyproject.toml): started
#   Building wheel for demucs (pyproject.toml): finished with status 'done'
#   Created wheel for demucs: filename=demucs-4.0.1-py3-none-any.whl size=78552 sha256=2cc54e6c7ac1be923fdea85fa47da84e563ffbf5c076fc88590ff2ddf60851a4
#   Stored in directory: c:\users\jiyon\appdata\local\pip\cache\wheels\1b\0c\20\a3b3daa1f9b65c8b0445729f94740ec335d0f86f1066c5c414
#   Building wheel for julius (pyproject.toml): started
#   Building wheel for julius (pyproject.toml): finished with status 'done'
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=22017 sha256=4eeb99c659b339d3f84f86100a972a55a3b6d0b39420cdf83715b577546d6e97
#   Stored in directory: c:\users\jiyon\appdata\local\pip\cache\wheels\de\c1\ca\544dafe48401e8e2e17064dfe465a390fca9e8720ffa12e744
#   Building wheel for dora-search (pyproject.toml): started
#   Building wheel for dora-search (pyproject.toml): finished with status 'done'
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75319 sha256=7c6111f087574f1e134f34d6b469dd2d872f7285850eca140ce630336c3708ab
#   Stored in directory: c:\users\jiyon\appdata\local\pip\cache\wheels\55\40\4c\3478187386b56625ab5aa8a9070ff1eea704ddb27d15abe73f
#   Building wheel for antlr4-python3-runtime (pyproject.toml): started
#   Building wheel for antlr4-python3-runtime (pyproject.toml): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144615 sha256=942a8bd4c37ce4596bd4f3a8ea7607d49da5bcc2b791d442c6560590b83dea93
#   Stored in directory: c:\users\jiyon\appdata\local\pip\cache\wheels\1f\be\48\13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
# Successfully built demucs julius dora-search antlr4-python3-runtime
# Installing collected packages: lameenc, antlr4-python3-runtime, treetable, retrying, omegaconf, einops, cloudpickle, torch, submitit, torchaudio, julius, dora-search, openunmix, demucs
#   Attempting uninstall: torch
#     Found existing installation: torch 2.7.1
#     Uninstalling torch-2.7.1:
#       Successfully uninstalled torch-2.7.1
# Successfully installed antlr4-python3-runtime-4.9.3 cloudpickle-3.1.1 demucs-4.0.1 dora-search-0.1.12 einops-0.8.1 julius-0.2.7 lameenc-1.8.1 omegaconf-2.3.0 openunmix-1.3.0 retrying-1.4.2 submitit-1.5.3 torch-2.8.0 torchaudio-2.8.0 treetable-0.2.6
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torchaudio
from demucs import pretrained
from demucs.apply import apply_model
import os

# Load pretrained Demucs model
model = pretrained.get_model('htdemucs')

# Define song pairs to process
song_pairs = [
    # (folder, original_song, ai_song)
    ("song1", "kanye.mp3", "kanye_new.mp3"),
    ("song2", "wap.mp3", "wap_new.mp3"), 
    ("song3", "islandgirl.mp3", "islandgirl_new.mp3"),
    ("song4", "whiteboy.mp3", "whiteboy_new.mp3")
]

def separate_vocals(input_path, output_vocals_path, output_instruments_path):
    """Separate vocals from a song and save both vocals and instruments"""
    try:
        # Load audio file
        wav, sr = torchaudio.load(input_path)
        
        # Add batch dimension
        wav = wav.unsqueeze(0)
        
        # Separate sources
        sources = apply_model(model, wav, split=True, progress=True)[0]
        sources_names = model.sources
        
        # Get vocals and instrumentals
        vocals = sources[sources_names.index("vocals")]
        instruments = sum(sources[i] for i, name in enumerate(sources_names) if name != "vocals")
        
        # Save results
        torchaudio.save(output_vocals_path, vocals, sr)
        torchaudio.save(output_instruments_path, instruments, sr)
        
        print(f"✓ Successfully processed: {input_path}")
        return True
        
    except Exception as e:
        print(f"✗ Error processing {input_path}: {e}")
        return False

# Process all song pairs
for folder, original_song, ai_song in song_pairs:
    print(f"\n--- Processing {folder} ---")
    
    # Create folder paths
    folder_path = f"./{folder}"
    
    # Process original song
    original_input = f"{folder_path}/{original_song}"
    original_vocals_output = f"{folder_path}/vocals.wav"
    original_instruments_output = f"{folder_path}/instruments.wav"
    
    if os.path.exists(original_input):
        separate_vocals(original_input, original_vocals_output, original_instruments_output)
    else:
        print(f"✗ File not found: {original_input}")
    
    # Process AI song  
    ai_input = f"{folder_path}/{ai_song}"
    ai_vocals_output = f"{folder_path}/vocals_ai.wav"
    ai_instruments_output = f"{folder_path}/instruments_ai.wav"
    
    if os.path.exists(ai_input):
        separate_vocals(ai_input, ai_vocals_output, ai_instruments_output)
    else:
        print(f"✗ File not found: {ai_input}")
# Out:
# --- Processing song1 ---
# 100%|██████████████████████████████████████████████| 163.79999999999998/163.79999999999998 [01:07<00:00,  2.44seconds/s]
# ✓ Successfully processed: ./song1/kanye.mp3
# 100%|██████████████████████████████████████████████| 140.39999999999998/140.39999999999998 [00:58<00:00,  2.41seconds/s]
# ✓ Successfully processed: ./song1/kanye_new.mp3
#
# --- Processing song2 ---
# 100%|████████████████████████████████████████████████████████████████████████| 210.6/210.6 [01:27<00:00,  2.41seconds/s]
# ✓ Successfully processed: ./song2/wap.mp3
# 100%|██████████████████████████████████████████████| 228.14999999999998/228.14999999999998 [01:36<00:00,  2.36seconds/s]
# ✓ Successfully processed: ./song2/wap_new.mp3
#
# --- Processing song3 ---
# 100%|██████████████████████████████████████████████| 228.14999999999998/228.14999999999998 [01:35<00:00,  2.40seconds/s]
# ✓ Successfully processed: ./song3/islandgirl.mp3
# 100%|████████████████████████████████████████████████████████████████████████| 245.7/245.7 [01:43<00:00,  2.37seconds/s]
# ✓ Successfully processed: ./song3/islandgirl_new.mp3
#
# --- Processing song4 ---
# 100%|██████████████████████████████████████████████| 298.34999999999997/298.34999999999997 [02:10<00:00,  2.28seconds/s]
# ✓ Successfully processed: ./song4/whiteboy.mp3
# 100%|██████████████████████████████████████████████| 280.79999999999995/280.79999999999995 [01:59<00:00,  2.34seconds/s]
# ✓ Successfully processed: ./song4/whiteboy_new.mp3
#
# --- Processing Complete ---
