# %%
# Out:
#                  ngram  freq ngram_type
# 0    ('n*gga', 'heil')    19     bigram
# 1   ('heil', 'hitler')    19     bigram
# 2  ('hitler', 'n*gga')     8     bigram
# 3    ('hitler', 'hey')     4     bigram
# 4     ('my', 'n*ggas')     4     bigram
# 5        ('all', 'my')     4     bigram
# 6     ('they', 'dont')     3     bigram
# 7    ('hitler', 'all')     3     bigram
# 8     ('hey', 'n*gga')     3     bigram
# 9   ('nazis', 'n*gga')     3     bigram
